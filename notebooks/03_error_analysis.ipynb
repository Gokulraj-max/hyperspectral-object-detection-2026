# %% [markdown]
# # Hyperspectral Object Detection Challenge 2026
# ## Notebook 03: Error Analysis & Model Diagnostics
# Analyzes model failure modes across 6 buckets: Correct Detection, False Positive, False Negative, Poor Localization, Wrong Class, and Duplicate Detection.

# %%
import os
import sys
import json
import matplotlib.pyplot as plt
import pandas as pd

sys.path.insert(0, "..")
from evaluation import CLASS_NAMES

# Load evaluation results if available
report_path = "../outputs/metrics/evaluation_report.txt"
if os.path.exists(report_path):
    with open(report_path, "r") as f:
        print(f.read())
else:
    print("Run evaluation/evaluate.py first to generate diagnostic metrics report.")
